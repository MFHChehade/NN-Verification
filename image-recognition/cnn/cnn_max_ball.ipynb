# %% [markdown]
# # Example: Optimal adversaries for convolutional MNIST model
#
# This notebook gives an example where OMLT is used to find adversarial examples for a trained convolutional neural network. We follow the below steps:<br>
# 1.) A convolutional neural network (CNN) with ReLU activation functions is trained to classify images from the MNIST dataset <br>
# 2.) OMLT is used to generate a mixed-integer encoding of the trained CNN using the big-M formulation <br>
# 3.) The model is optimized to find the maximum classification error (defined by an "adversarial" label) over a small input region <br>

# %% [markdown]
# ## Library Setup
# This notebook assumes you have a working PyTorch environment to train the neural network for classification. The neural network is then formulated in Pyomo using OMLT which therefore requires working Pyomo and OMLT installations.
#
# The required Python libraries used this notebook are as follows: <br>
# - `numpy`: used for manipulate input data <br>
# - `torch`: the machine learning language we use to train our neural network
# - `torchvision`: a package containing the MNIST dataset
# - `pyomo`: the algebraic modeling language for Python, it is used to define the optimization model passed to the solver
# - `onnx`: used to express trained neural network models
# - `omlt`: the package this notebook demonstates. OMLT can formulate machine learning models (such as neural networks) within Pyomo
#
# **NOTE:** This notebook also assumes you have a working MIP solver executable (e.g., CBC, Gurobi) to solve optimization problems in Pyomo. The open-source solver CBC is called by default.

# %%
#Import requisite packages
#data manipulation
import numpy as np
import tempfile

#pytorch for training neural network
import torch, torch.onnx
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR

#pyomo for optimization
import pyomo.environ as pyo

#omlt for interfacing our neural network with pyomo
from omlt import OmltBlock
from omlt.neuralnet import FullSpaceNNFormulation
from omlt.io.onnx import write_onnx_model_with_bounds, load_onnx_neural_network_with_bounds

# %% [markdown]
# ## Import the Data and Train a Neural Network
#
# We begin by loading the MNIST dataset as `DataLoader` objects with pre-set training and testing batch sizes:

# %%
#set training and test batch sizes
train_kwargs = {'batch_size': 64}
test_kwargs = {'batch_size': 1000}

#build DataLoaders for training and test sets
dataset1 = datasets.MNIST('../data', train=True, download=True, transform=transforms.ToTensor())
dataset2 = datasets.MNIST('../data', train=False, transform=transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(dataset1,**train_kwargs, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset2, **test_kwargs)

# %% [markdown]
# ## Build a MIP Formulation for the Trained Convolutional Neural Network
#
# We are now ready to use OMLT to formulate the trained model within a Pyomo optimization model. We use a  binary variable representation to represent the ReLU activation logic which is created automatically using the `FullSpaceNNFormulation` object (one could also simply use the `ReluBigFormulation` object).

# %% [markdown]
# First, we define a neural network without the final `LogSoftmax` activation. Although this activation helps greatly in training the neural network model, it is not trivial to encode in the optimization model. The ranking of the output labels remains the same without the activation, so it can be omitted when finding optimal adversaries.

# %%
hidden_size = 10

class NoSoftmaxNet(nn.Module):
    #define layers of neural network
    def __init__(self):
        super().__init__()
        self.conv1  = nn.Conv2d(1, 2, (4,4), (2,2), 0)
        self.conv2  = nn.Conv2d(2, 2, (4,4), (2,2), 0)
        self.hidden1 = nn.Linear(5 * 5 * 2, hidden_size)
        self.output  = nn.Linear(hidden_size, 10)
        self.relu = nn.ReLU()

    #define forward pass of neural network
    def forward(self, x):
        self.x1 = self.conv1(x)
        self.x2 = self.relu(self.x1)
        self.x3 = self.conv2(self.x2)
        self.x4 = self.relu(self.x3)
        self.x5 = self.hidden1(self.x4.view((-1,5*5*2)))
        self.x6 = self.relu(self.x5)
        x = self.output(self.x6)    
        return x

# %%
import torch

# Path to the saved model
model_path = "cnn_model.pth"

# Load the model
model = NoSoftmaxNet()
model.load_state_dict(torch.load(model_path))

print("Model loaded successfully.")
# Out:
# Model loaded successfully.

# %% [markdown]
# Next, we define an instance of the optimal adversary problem. We formulate the optimization problem as: <br>
#
# $
# \begin{align*}
# & \max_x \ y_k - y_j \\
# & s.t. y_k = N_k(x) \\
# &\quad |x - \bar{x}|_\infty \leq 0.05
# \end{align*}
# $
#
# where $\bar{x}$ corresponds to an image in the test dataset with true label `j`, and $N_k(x)$ is the value of the CNN output corresponding to adversarial label `k` given input `x`. PyTorch needs to trace the model execution to export it to ONNX, so we also define a dummy input tensor `x_temp`.

# %%
#load image and true label from test set with index 'problem_index'
problem_index = 0
image = dataset2[problem_index][0].detach().numpy()
label = dataset2[problem_index][1]

#define input region defined by infinity norm
epsilon_infty = 0.1
lb = np.maximum(0, image - epsilon_infty)
ub = np.minimum(1, image + epsilon_infty)

#save input bounds as dictionary, note that the first index 0 corresponds to the single-channel input
input_bounds = {}
for i in range(28):
    for j in range(28):
        input_bounds[(0,i,j)] = (float(lb[0][i,j]), float(ub[0][i,j])) 
    
#define dummy input tensor    
x = dataset2[problem_index][0].view(-1,1,28,28)

# %% [markdown]
# We can now export the PyTorch model as an ONNX model and use `load_onnx_neural_network_with_bounds` to load it into OMLT.

# %%
with tempfile.NamedTemporaryFile(suffix='.onnx', delete=False) as f:
    #export neural network to ONNX
    torch.onnx.export(
        model,
        x,
        f,
        input_names=['input'],
        output_names=['output'],
        dynamic_axes={
            'input': {0: 'batch_size'},
            'output': {0: 'batch_size'}
        }
    )
    #write ONNX model and its bounds using OMLT
    write_onnx_model_with_bounds(f.name, None, input_bounds)
    #load the network definition from the ONNX model
    network_definition = load_onnx_neural_network_with_bounds(f.name)

# %% [markdown]
# As a sanity check before creating the optimization model, we can print the properties of the neural network layers from `network_definition`. This allows us to check input/output sizes, as well as activation functions.

# %%
for layer_id, layer in enumerate(network_definition.layers):
    print(f"{layer_id}\t{layer}\t{layer.activation}")
# Out:
# 0	InputLayer(input_size=[1, 28, 28], output_size=[1, 28, 28])	linear
# 1	ConvLayer(input_size=[1, 28, 28], output_size=[2, 13, 13], strides=[2, 2], kernel_shape=(4, 4))	relu
# 2	ConvLayer(input_size=[2, 13, 13], output_size=[2, 5, 5], strides=[2, 2], kernel_shape=(4, 4))	relu
# 3	DenseLayer(input_size=[1, 50], output_size=[1, 10])	relu
# 4	DenseLayer(input_size=[1, 10], output_size=[1, 10])	linear

# %% [markdown]
# Finally, we can load `network_definition` as a full-space `FullSpaceNNFormulation` object.OMLT doesn't include a formulation for sigmoid, so define it here

# %%
formulation = FullSpaceNNFormulation(network_definition)

# %% [markdown]
# ## Solve Optimal Adversary Problem in Pyomo
#
# We now encode the trained neural network in a Pyomo model from the `FullSpaceNNFormulation` object.

# %%
#create pyomo model
m = pyo.ConcreteModel()

#create an OMLT block for the neural network and build its formulation
m.nn = OmltBlock()
m.nn.build_formulation(formulation)
# Out:
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,7,6]' to a numeric value `0`
# outside the bounds (0.229411780834198, 0.42941176891326904).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,7,7]' to a numeric value `0`
# outside the bounds (0.6254901885986328, 0.8254902362823486).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,7,8]' to a numeric value `0`
# outside the bounds (0.5235294103622437, 0.7235294580459595).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,7,9]' to a numeric value `0`
# outside the bounds (0.49215689301490784, 0.6921569108963013).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,7,10]' to a numeric value `0`
# outside the bounds (0.135294109582901, 0.33529412746429443).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,7,11]' to a numeric value `0`
# outside the bounds (0.04117647558450699, 0.24117648601531982).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,6]' to a numeric value `0`
# outside the bounds (0.770588219165802, 0.9705882668495178).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,7]' to a numeric value `0`
# outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,8]' to a numeric value `0`
# outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,9]' to a numeric value `0`
# outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,10]' to a numeric value `0`
# outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,11]' to a numeric value `0`
# outside the bounds (0.8450980186462402, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,12]' to a numeric value `0`
# outside the bounds (0.6764705777168274, 0.8764706254005432).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,13]' to a numeric value `0`
# outside the bounds (0.6764705777168274, 0.8764706254005432).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,14]' to a numeric value `0`
# outside the bounds (0.6764705777168274, 0.8764706254005432).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,15]' to a numeric value `0`
# outside the bounds (0.6764705777168274, 0.8764706254005432).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,16]' to a numeric value `0`
# outside the bounds (0.6764705777168274, 0.8764706254005432).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,17]' to a numeric value `0`
# outside the bounds (0.6764705777168274, 0.8764706254005432).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,18]' to a numeric value `0`
# outside the bounds (0.6764705777168274, 0.8764706254005432).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,19]' to a numeric value `0`
# outside the bounds (0.6764705777168274, 0.8764706254005432).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,20]' to a numeric value `0`
# outside the bounds (0.5666666626930237, 0.7666667103767395).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,8,21]' to a numeric value `0`
# outside the bounds (0.1039215698838234, 0.30392158031463623).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,6]' to a numeric value `0`
# outside the bounds (0.16274511814117432, 0.36274510622024536).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,7]' to a numeric value `0`
# outside the bounds (0.34705883264541626, 0.5470588207244873).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,8]' to a numeric value `0`
# outside the bounds (0.1823529601097107, 0.38235294818878174).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,9]' to a numeric value `0`
# outside the bounds (0.34705883264541626, 0.5470588207244873).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,10]' to a numeric value `0`
# outside the bounds (0.5392156839370728, 0.7392157316207886).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,11]' to a numeric value `0`
# outside the bounds (0.7901960611343384, 0.9901961088180542).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,12]' to a numeric value `0`
# outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,13]' to a numeric value `0`
# outside the bounds (0.7823529243469238, 0.9823529720306396).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,14]' to a numeric value `0`
# outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,15]' to a numeric value `0`
# outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,16]' to a numeric value `0`
# outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,17]' to a numeric value `0`
# outside the bounds (0.8803921341896057, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,18]' to a numeric value `0`
# outside the bounds (0.7980391979217529, 0.9980392456054688).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,19]' to a numeric value `0`
# outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,20]' to a numeric value `0`
# outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,9,21]' to a numeric value `0`
# outside the bounds (0.4490196406841278, 0.6490196585655212).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,10,12]' to a numeric value
# `0` outside the bounds (0.15882354974746704, 0.3588235378265381).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,10,14]' to a numeric value
# `0` outside the bounds (0.16274511814117432, 0.36274510622024536).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,10,15]' to a numeric value
# `0` outside the bounds (0.16274511814117432, 0.36274510622024536).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,10,16]' to a numeric value
# `0` outside the bounds (0.16274511814117432, 0.36274510622024536).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,10,17]' to a numeric value
# `0` outside the bounds (0.13137254118919373, 0.33137255907058716).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,10,19]' to a numeric value
# `0` outside the bounds (0.8254901766777039, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,10,20]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,10,21]' to a numeric value
# `0` outside the bounds (0.31568628549575806, 0.5156862735748291).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,11,18]' to a numeric value
# `0` outside the bounds (0.22549021244049072, 0.42549020051956177).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,11,19]' to a numeric value
# `0` outside the bounds (0.8921568393707275, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,11,20]' to a numeric value
# `0` outside the bounds (0.7196078300476074, 0.9196078777313232).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,12,18]' to a numeric value
# `0` outside the bounds (0.813725471496582, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,12,19]' to a numeric value
# `0` outside the bounds (0.8999999761581421, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,12,20]' to a numeric value
# `0` outside the bounds (0.22549021244049072, 0.42549020051956177).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,13,17]' to a numeric value
# `0` outside the bounds (0.4058823883533478, 0.6058824062347412).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,13,18]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,13,19]' to a numeric value
# `0` outside the bounds (0.8333333134651184, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,13,20]' to a numeric value
# `0` outside the bounds (0.07254902273416519, 0.272549033164978).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,14,16]' to a numeric value
# `0` outside the bounds (0.13137254118919373, 0.33137255907058716).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,14,17]' to a numeric value
# `0` outside the bounds (0.8764705657958984, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,14,18]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,14,19]' to a numeric value
# `0` outside the bounds (0.14313724637031555, 0.343137264251709).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,15,16]' to a numeric value
# `0` outside the bounds (0.4215686619281769, 0.6215686798095703).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,15,17]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,15,18]' to a numeric value
# `0` outside the bounds (0.6333333253860474, 0.8333333730697632).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,16,16]' to a numeric value
# `0` outside the bounds (0.7039215564727783, 0.9039216041564941).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,16,17]' to a numeric value
# `0` outside the bounds (0.8725489974021912, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,16,18]' to a numeric value
# `0` outside the bounds (0.12745097279548645, 0.3274509906768799).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,17,15]' to a numeric value
# `0` outside the bounds (0.39411765336990356, 0.5941176414489746).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,17,16]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,17,17]' to a numeric value
# `0` outside the bounds (0.613725483417511, 0.8137255311012268).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,18,14]' to a numeric value
# `0` outside the bounds (0.19411766529083252, 0.39411765336990356).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,18,15]' to a numeric value
# `0` outside the bounds (0.884313702583313, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,18,16]' to a numeric value
# `0` outside the bounds (0.841176450252533, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,18,17]' to a numeric value
# `0` outside the bounds (0.12352941185235977, 0.3235294222831726).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,19,14]' to a numeric value
# `0` outside the bounds (0.7666666507720947, 0.9666666984558105).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,19,15]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,19,16]' to a numeric value
# `0` outside the bounds (0.5509803891181946, 0.7509804368019104).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,20,13]' to a numeric value
# `0` outside the bounds (0.6960784196853638, 0.8960784673690796).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,20,14]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,20,15]' to a numeric value
# `0` outside the bounds (0.7588235139846802, 0.958823561668396).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,20,16]' to a numeric value
# `0` outside the bounds (0.03725490719079971, 0.23725491762161255).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,21,12]' to a numeric value
# `0` outside the bounds (0.04901961237192154, 0.24901962280273438).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,21,13]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,21,14]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,21,15]' to a numeric value
# `0` outside the bounds (0.20196080207824707, 0.4019607901573181).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,22,11]' to a numeric value
# `0` outside the bounds (0.021568626165390015, 0.22156862914562225).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,22,12]' to a numeric value
# `0` outside the bounds (0.7784313559532166, 0.9784314036369324).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,22,13]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,22,14]' to a numeric value
# `0` outside the bounds (0.35098040103912354, 0.5509803891181946).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,23,11]' to a numeric value
# `0` outside the bounds (0.4215686619281769, 0.6215686798095703).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,23,12]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,23,13]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,23,14]' to a numeric value
# `0` outside the bounds (0.1039215698838234, 0.30392158031463623).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,24,10]' to a numeric value
# `0` outside the bounds (0.13921567797660828, 0.3392156958580017).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,24,11]' to a numeric value
# `0` outside the bounds (0.8490195870399475, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,24,12]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,24,13]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,24,14]' to a numeric value
# `0` outside the bounds (0.1039215698838234, 0.30392158031463623).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,25,10]' to a numeric value
# `0` outside the bounds (0.3745098114013672, 0.5745097994804382).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,25,11]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,25,12]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,25,13]' to a numeric value
# `0` outside the bounds (0.7588235139846802, 0.958823561668396).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,25,14]' to a numeric value
# `0` outside the bounds (0.05686274915933609, 0.2568627595901489).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,26,10]' to a numeric value
# `0` outside the bounds (0.3745098114013672, 0.5745097994804382).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,26,11]' to a numeric value
# `0` outside the bounds (0.8960784077644348, 1.0).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'nn.scaled_inputs[0,26,12]' to a numeric value
# `0` outside the bounds (0.7117646932601929, 0.9117647409439087).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002

# %%
l1_norm_ball = False
l2_norm_ball = False

input_size = 28

# Variable representing the auxiliary variable for L1 norm
if ( not l1_norm_ball and not l2_norm_ball):
    m.auxiliary = pyo.Var(range(input_size), domain=pyo.NonNegativeReals)

if l1_norm_ball:
    # make the range of the auxiliary variable to be the same as the input
    m.auxiliary = pyo.Var(range(0, input_size), range(0, input_size), domain=pyo.NonNegativeReals)

# %%
m.input = pyo.Var(range(28), range(28), within=pyo.Reals)
m.output = pyo.Var(range(10), domain=pyo.Reals)

# %%
m.connect_inputs = pyo.ConstraintList()
m.connect_outputs = pyo.ConstraintList()

for i in range(28):
    for j in range(28):
        m.connect_inputs.add(m.input[i,j] == m.nn.inputs[0,i,j])
for j in range(10):  # For output connections
    m.connect_outputs.add(m.output[j] == m.nn.outputs[0,j])

# %%
# booleans to know what is the adversary

digit0_adversary = False
digit1_adversary = False
digit2_adversary = False
digit3_adversary = True
digit4_adversary = False
digit5_adversary = False
digit6_adversary = False
digit7_adversary = False
digit8_adversary = False
digit9_adversary = False

digits_adversary = [digit0_adversary, digit1_adversary, digit2_adversary, digit3_adversary, digit4_adversary, digit5_adversary, digit6_adversary, digit7_adversary, digit8_adversary, digit9_adversary]

# assert only one digit hot
assert sum(digits_adversary) == 1, "Only one digit can be the adversary"

# assert not the true label is the adversary 
assert not digits_adversary[label], "The true label cannot be the adversary"

# %%
center = image[0]
input_neurons = 28
assert len(center) == input_neurons, "Center should have the same size as the input"

if l1_norm_ball:
    # constraint list
    m.l1_constraints = pyo.ConstraintList()
    # add that each difference must be less than auxiliary
    # and greater than negative auxiliary
    for i in range(input_neurons):
        for j in range(input_neurons):
            m.l1_constraints.add(m.input[i,j] - center[i,j] <= m.auxiliary[i,j])
            m.l1_constraints.add(-m.auxiliary[i,j] <= m.input[i,j] - center[i,j])


elif l1_norm_ball == False and l2_norm_ball == False:
    # constraint list
    m.l1_constraints = pyo.ConstraintList()
    # add that each difference must be less than auxiliary
    # and greater than negative auxiliary
    for i in range(input_neurons):
        for j in range(input_neurons):
            m.l1_constraints.add(m.input[i,j] - center[i,j] <= m.auxiliary[i])
            m.l1_constraints.add(-m.auxiliary[i] <= m.input[i,j] - center[i,j])

# %%
if l1_norm_ball:
    m.obj = pyo.Objective(expr=sum(m.auxiliary[i, j] for i in range(input_neurons) for j in range(input_neurons)), sense=pyo.minimize)
elif l2_norm_ball: 
    m.obj = model.obj = pyo.Objective(expr=sum((model.input[i, j] - center[i][j]) ** 2 for i in range(input_neurons) for j in range(input_neurons)), sense=pyo.minimize)
else:
   m.obj = pyo.Objective(expr=sum(m.auxiliary[i] for i in range(input_neurons)), sense=pyo.minimize)

# %%
# construt the property of the output f(x)
# f(x) = - (output[label] - output[adversary])
# we need f(x) + margin <= 0

margin = 1e-3 # margin to convert strict inequality to non-strict

hot_digit = digits_adversary.index(True)
m.output_property = pyo.Constraint(expr = m.output[label] - m.output[hot_digit] + margin <= 0)

# %% [markdown]
# Next, we define an adversarial label as the true label plus one (or zero if the true label is nine), as well as the objective function for optimization.

# %% [markdown]
# Finally, we solve the optimal adversary problem using a mixed-integer solver.

# %%
solver = pyo.SolverFactory('cbc')
solver.solve(m, tee=True)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.9.7
# Build Date: Oct 10 2015
# Revision Number: 2226
#
# command line - C:\CBC\win32-msvc12\bin\cbc.exe -printingOptions all -import C:\Users\HP\AppData\Local\Temp\tmpwqk4axc7.pyomo.lp -stat=1 -solve -solu C:\Users\HP\AppData\Local\Temp\tmpwqk4axc7.pyomo.soln (default strategy 1)
# Option for printingOptions changed from normal to all
# Presolve 2267 (-3694) rows, 1787 (-2621) columns and 11837 (-7173) elements
# Statistics for presolved model
# Original problem has 398 integers (398 of which binary)
# Presolved problem has 185 integers (185 of which binary)
# ==== 1759 zero objective 2 different
# 1759 variables have objective of 0
# 28 variables have objective of 1
# ==== absolute objective values 2 different
# 1759 variables have objective of 0
# 28 variables have objective of 1
# ==== for integers 185 zero objective 1 different
# 185 variables have objective of 0
# ==== for integers absolute objective values 1 different
# 185 variables have objective of 0
# ===== end objective counts
#
#
# Problem has 2267 rows, 1787 columns (28 with objective) and 11837 elements
# Column breakdown:
# 28 of type 0.0->inf, 1189 of type 0.0->up, 0 of type lo->inf,
# 385 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 185 of type 0.0->1.0
# Row breakdown:
# 382 of type E 0.0, 0 of type E 1.0, 0 of type E -1.0,
# 10 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 0 of type G other, 1458 of type L 0.0, 0 of type L 1.0,
# 417 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Continuous objective value is 0 - 0.07 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 37 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 1862 rows, 1382 columns (162 integer (162 of which binary)) and 17238 elements
# Cbc0038I Initial state - 69 integers unsatisfied sum - 11.3944
# Cbc0038I Pass   1: suminf.    1.72853 (13) obj. 2.43447 iterations 2240
# Cbc0038I Pass   2: suminf.    0.18877 (1) obj. 2.57059 iterations 1426
# Cbc0038I Pass   3: suminf.    0.27633 (1) obj. 2.57141 iterations 1630
# Cbc0038I Pass   4: suminf.    0.55931 (4) obj. 2.5748 iterations 923
# Cbc0038I Pass   5: suminf.    0.16534 (2) obj. 2.61688 iterations 1610
# Cbc0038I Pass   6: suminf.    0.25682 (2) obj. 2.57871 iterations 1741
# Cbc0038I Pass   7: suminf.    0.74111 (3) obj. 2.73738 iterations 1009
# Cbc0038I Pass   8: suminf.    0.16547 (1) obj. 2.64461 iterations 1361
# Cbc0038I Pass   9: suminf.    0.25808 (1) obj. 2.6942 iterations 1672
# Cbc0038I Pass  10: suminf.    1.10622 (6) obj. 2.8 iterations 1119
# Cbc0038I Pass  11: suminf.    0.26756 (2) obj. 2.8 iterations 865
# Cbc0038I Pass  12: suminf.    0.17411 (1) obj. 2.8 iterations 1118
# Cbc0038I Pass  13: suminf.    0.68257 (4) obj. 2.8 iterations 1199
# Cbc0038I Pass  14: suminf.    0.22884 (1) obj. 2.8 iterations 2097
# Cbc0038I Pass  15: suminf.    0.14732 (1) obj. 2.8 iterations 1302
# Cbc0038I Pass  16: suminf.    0.81523 (5) obj. 2.6 iterations 1393
# Cbc0038I Pass  17: suminf.    0.31380 (1) obj. 2.63865 iterations 1828
# Cbc0038I Pass  18: suminf.    0.20642 (1) obj. 2.62057 iterations 1048
# Cbc0038I Pass  19: suminf.    0.63528 (5) obj. 2.67902 iterations 1031
# Cbc0038I Pass  20: suminf.    0.37020 (1) obj. 2.8 iterations 1370
# Cbc0038I Pass  21: suminf.    0.25553 (1) obj. 2.8 iterations 744
# Cbc0038I Pass  22: suminf.    0.65797 (7) obj. 2.8 iterations 1253
# Cbc0038I Pass  23: suminf.    0.21408 (1) obj. 2.8 iterations 2000
# Cbc0038I Pass  24: suminf.    0.12793 (1) obj. 2.8 iterations 1123
# Cbc0038I Pass  25: suminf.    0.48071 (3) obj. 2.70392 iterations 738
# Cbc0038I Pass  26: suminf.    0.26119 (1) obj. 2.8 iterations 1902
# Cbc0038I Pass  27: suminf.    0.17982 (1) obj. 2.8 iterations 1013
# Cbc0038I Pass  28: suminf.    1.25552 (7) obj. 2.61639 iterations 1326
# Cbc0038I Pass  29: suminf.    0.15721 (1) obj. 2.66367 iterations 1948
# Cbc0038I Pass  30: suminf.    0.12408 (1) obj. 2.66367 iterations 1004
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 157 continuous
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 1671 rows 1191 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (8.58 seconds)
# Cbc0038I Full problem 1863 rows 1382 columns, reduced to 1863 rows 1382 columns - too large
# Cbc0038I After 9.49 seconds - Feasibility pump exiting - took 8.91 seconds
# Cbc0031I 77 added rows had average density of 45.246753
# Cbc0013I At root node, 77 cuts changed objective from 0 to 0 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 22 row cuts average 21.5 elements, 0 column cuts (0 active)  in 0.046 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 152 row cuts average 78.0 elements, 0 column cuts (0 active)  in 0.051 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 3 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.064 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 217 row cuts average 23.3 elements, 0 column cuts (0 active)  in 0.027 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 1 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.061 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 143 row cuts average 84.3 elements, 0 column cuts (0 active)  in 0.065 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+050 best solution, best possible 0 (12.97 seconds)
# Cbc0010I After 100 nodes, 60 on tree, 1e+050 best solution, best possible 0 (38.25 seconds)
# Cbc0010I After 200 nodes, 104 on tree, 1e+050 best solution, best possible 0 (73.08 seconds)
# Cbc0010I After 300 nodes, 154 on tree, 1e+050 best solution, best possible 0 (99.79 seconds)
# Cbc0010I After 400 nodes, 198 on tree, 1e+050 best solution, best possible 0 (118.26 seconds)
# Cbc0010I After 500 nodes, 235 on tree, 1e+050 best solution, best possible 0 (134.47 seconds)
# Cbc0004I Integer solution of 2.3934025 found after 361913 iterations and 522 nodes (135.23 seconds)
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 1767 rows 1287 columns - 21 fixed gives 1744, 1264 - still too large
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 1735 rows 1255 columns - 16 fixed gives 1719, 1239 - still too large
# Cbc0010I After 600 nodes, 256 on tree, 2.3934025 best solution, best possible 0 (149.43 seconds)
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 1747 rows 1266 columns - 20 fixed gives 1727, 1246 - still too large
# Cbc0010I After 700 nodes, 290 on tree, 2.3934025 best solution, best possible 0 (171.14 seconds)
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 1066 rows 834 columns - 17 fixed gives 1049, 816 - still too large
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 1038 rows 811 columns - too large
# Cbc0010I After 800 nodes, 328 on tree, 2.3934025 best solution, best possible 0 (192.91 seconds)
# Cbc0012I Integer solution of 2.336175 found by rounding after 521621 iterations and 827 nodes (197.74 seconds)
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 1050 rows 797 columns - 13 fixed gives 1039, 785 - still too large
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 1027 rows 778 columns - too large
# Cbc0010I After 900 nodes, 341 on tree, 2.336175 best solution, best possible 0 (224.82 seconds)
# Cbc0012I Integer solution of 2.168955 found by rounding after 569609 iterations and 909 nodes (226.27 seconds)
# Cbc0012I Integer solution of 2.1687971 found by rounding after 602770 iterations and 994 nodes (250.09 seconds)
# Cbc0010I After 1000 nodes, 352 on tree, 2.1687971 best solution, best possible 0 (251.24 seconds)
# Cbc0012I Integer solution of 1.7689817 found by rounding after 607443 iterations and 1078 nodes (256.78 seconds)
# Cbc0010I After 1100 nodes, 374 on tree, 1.7689817 best solution, best possible 0 (260.79 seconds)
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 895 rows 647 columns
# Cbc0010I After 1200 nodes, 369 on tree, 1.7689817 best solution, best possible 0 (274.82 seconds)
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 978 rows 728 columns - 22 fixed gives 961, 708 - still too large
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 954 rows 703 columns - too large
# Cbc0010I After 1300 nodes, 391 on tree, 1.7689817 best solution, best possible 0 (291.08 seconds)
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 983 rows 733 columns - 9 fixed gives 973, 723 - still too large
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 963 rows 716 columns - too large
# Cbc0010I After 1400 nodes, 419 on tree, 1.7689817 best solution, best possible 0 (304.55 seconds)
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 956 rows 702 columns - 7 fixed gives 950, 695 - still too large
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 947 rows 695 columns - too large
# Cbc0010I After 1500 nodes, 446 on tree, 1.7689817 best solution, best possible 0 (320.40 seconds)
# Cbc0010I After 1600 nodes, 479 on tree, 1.7689817 best solution, best possible 0 (340.74 seconds)
# Cbc0010I After 1700 nodes, 508 on tree, 1.7689817 best solution, best possible 0 (357.90 seconds)
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 973 rows 723 columns - 17 fixed gives 958, 706 - still too large
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 949 rows 700 columns - too large
# Cbc0010I After 1800 nodes, 539 on tree, 1.7689817 best solution, best possible 0 (372.92 seconds)
# Cbc0010I After 1900 nodes, 571 on tree, 1.7689817 best solution, best possible 0 (399.37 seconds)
# Cbc0010I After 2000 nodes, 603 on tree, 1.7689817 best solution, best possible 0 (422.81 seconds)
# Cbc0010I After 2100 nodes, 632 on tree, 1.7689817 best solution, best possible 0 (444.65 seconds)
# Cbc0010I After 2200 nodes, 657 on tree, 1.7689817 best solution, best possible 0 (470.08 seconds)
# Cbc0010I After 2300 nodes, 703 on tree, 1.7689817 best solution, best possible 0 (481.99 seconds)
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to 963 rows 713 columns - 12 fixed gives 953, 702 - still too large
# Cbc0038I Full problem 1862 rows 1382 columns, reduced to
seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.12334968
# Enumerated nodes:               24801
# Total iterations:               7166660
# Time (CPU seconds):             3605.53
# Time (Wallclock seconds):       3605.53
#
# Total time (CPU seconds):       3605.74   (Wallclock seconds):       3605.74
# {'Problem': [{'Name': 'unknown', 'Lower bound': 1.12334968, 'Upper bound': 1.12334968, 'Number of objectives': 1, 'Number of constraints': 2267, 'Number of variables': 1787, 'Number of binary variables': 398, 'Number of integer variables': 398, 'Number of nonzeros': 28, 'Sense': 'minimize'}], 'Solver': [{'Status': 'ok', 'User time': -1.0, 'System time': 3605.74, 'Wallclock time': 3605.74, 'Termination condition': 'optimal', 'Termination message': 'Model was solved to optimality (subject to tolerances), and an optimal solution is available.', 'Statistics': {'Branch and bound': {'Number of bounded subproblems': 24801, 'Number of created subproblems': 24801}, 'Black box': {'Number of iterations': 7166660}}, 'Error rc': 0, 'Time': 3605.9748871326447}], 'Solution': [OrderedDict([('number of solutions', 0), ('number of solutions displayed', 0)])]}

# %%
# print the output of the neural network 
# print the objective function

print(f"true label: {label}")
print(f"adversary label: {hot_digit}")

print()

for i in range(10):
    print(f"output {i}: {m.nn.outputs[0,i].value}", end = " ")
    print(f"Diff = {m.nn.outputs[0,i].value - m.nn.outputs[0,label].value}")

print()

print(f"objective function: {m.obj()}")
# Out:
# true label: 7
# adversary label: 3
#
# output 0: -2.667971 Diff = -5.7748674
# output 1: -15.815524 Diff = -18.9224204
# output 2: -1.5044647 Diff = -4.6113611
# output 3: 3.1078964 Diff = 0.0009999999999998899
# output 4: -14.346785 Diff = -17.4536814
# output 5: -3.3671815 Diff = -6.4740779
# output 6: -25.997231 Diff = -29.1041274
# output 7: 3.1068964 Diff = 0.0
# output 8: -3.2370006 Diff = -6.343897
# output 9: -3.0671732 Diff = -6.1740696
#
# objective function: 1.1233496502

# %%
import torch
import matplotlib.pyplot as plt

# Create a torch tensor for the adversarial input, assuming it's flattened
input = torch.zeros((28,28))

# Assuming m.input contains the perturbed image values from a Pyomo model
for i in range(28):
    for j in range(28):
        input[i,j] = m.nn.inputs[0,i,j].value

# Reshape the adversarial example to a 28x28 array for visualization
image_data = input.numpy()  # Convert to numpy array if not already

# Assuming 'image' is another 28x28 array you want to plot for comparison
# Ensure 'image' is also a numpy array and correctly shaped
image = image.reshape(28,28)

# Create a figure with 2 subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Plot the adversarial example
adversarial_display = axes[0].imshow(image_data, cmap='gray')
axes[0].set_title('Adversarial Example')

plt.colorbar(adversarial_display, ax=axes[0])  # Add colorbar associated with the first subplot
comparison_display = axes[1].imshow(image, cmap='gray')
axes[1].set_title('Comparison Image')
# Plot the original or comparison image
plt.colorbar(comparison_display, ax=axes[1])  # Add colorbar associated with the second subplot

plt.show()

# %%
# print the output of the neural network 
# print the objective function

print(f"true label: {label}")
print(f"adversary label: {adversary}")

print()

for i in range(10):
    print(f"output {i}: {m.nn.outputs[0,i].value}", end = " ")
    print(f"Diff = {m.nn.outputs[0,i].value - m.nn.outputs[0,label].value}")

print()

print(f"objective function: {m.obj()}")
# Out:
# true label: 7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 5
#       1 # print the output of the neural network
#       2 # print the objective function
#       4 print(f"true label: {label}")
# ----> 5 print(f"adversary label: {adversary}")
#       7 print()
#       9 for i in range(10):
#
# NameError: name 'adversary' is not defined

# %% [markdown]
# ### worst adversary

# %%
max_classification_error_check = True
if max_classification_error_check:
    
    max_classification_error = np.inf
    most_adv_label = None

    for adversary in range(10):
        
        if adversary == label:
            continue
        m.obj = pyo.Objective(expr=(-(m.nn.outputs[0,adversary]-m.nn.outputs[0,label])), sense=pyo.minimize)
        pyo.SolverFactory('cbc').solve(m, tee=True)
        print(f"objective function: {m.obj()}")

        if m.obj() < max_classification_error:
            max_classification_error = m.obj()
            most_adv_label = adversary
# Out:
# WARNING: Implicitly replacing the Component attribute obj (type=<class
# 'pyomo.core.base.objective.ScalarObjective'>) on block unknown with a new
# Component (type=<class 'pyomo.core.base.objective.ScalarObjective'>). This is
# usually indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# Welcome to the CBC MILP Solver
# Version: 2.9.7
# Build Date: Oct 10 2015
# Revision Number: 2226
#
# command line - C:\CBC\win32-msvc12\bin\cbc.exe -printingOptions all -import C:\Users\HP\AppData\Local\Temp\tmptxssd3qc.pyomo.lp -stat=1 -solve -solu C:\Users\HP\AppData\Local\Temp\tmptxssd3qc.pyomo.soln (default strategy 1)
# Option for printingOptions changed from normal to all
# Presolve 1353 (-2245) rows, 1749 (-1837) columns and 9936 (-4350) elements
# Statistics for presolved model
# Original problem has 398 integers (398 of which binary)
# Presolved problem has 180 integers (180 of which binary)
# ==== 1738 zero objective 12 different
# ==== absolute objective values 12 different
# ==== for integers 180 zero objective 1 different
# 180 variables have objective of 0
# ==== for integers absolute objective values 1 different
# 180 variables have objective of 0
# ===== end objective counts
#
#
# Problem has 1353 rows, 1749 columns (11 with objective) and 9936 elements
# There are 1 singletons with objective
# Column breakdown:
# 0 of type 0.0->inf, 1177 of type 0.0->up, 0 of type lo->inf,
# 392 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 180 of type 0.0->1.0
# Row breakdown:
# 379 of type E 0.0, 0 of type E 1.0, 0 of type E -1.0,
# 11 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 0 of type G other, 783 of type L 0.0, 0 of type L 1.0,
# 180 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Continuous objective value is -21.7716 - 0.06 seconds
# Cgl0003I 1 fixed, 0 tightened bounds, 46 strengthened rows, 0 substitutions
# Cgl0003I 2 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 941 rows, 1335 columns (151 integer (151 of which binary)) and 15144 elements
# Cbc0038I Initial state - 122 integers unsatisfied sum - 30.9522
# Cbc0038I Pass   1: suminf.    1.11559 (9) obj. 8.28703 iterations 913
# Cbc0038I Solution found of 8.28703
# Cbc0038I Relaxing continuous gives 7.04034
# Cbc0038I Before mini branch and bound, 28 integers at bound fixed and 520 continuous
# Cbc0038I Full problem 941 rows 1335 columns, reduced to 848 rows 771 columns - 21 fixed gives 828, 751 - still too large
# Cbc0038I Full problem 941 rows 1335 columns, reduced to 777 rows 704 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (1.14 seconds)
# Cbc0038I Round again with cutoff of 6.4585
# Cbc0038I Pass   2: suminf.    1.41475 (8) obj. 6.4585 iterations 168
# Cbc0038I Pass   3: suminf.    0.17208 (1) obj. 6.4585 iterations 1079
# Cbc0038I Pass   4: suminf.    0.32817 (1) obj. 6.4585 iterations 428
# Cbc0038I Pass   5: suminf.    1.36406 (7) obj. 6.4585 iterations 803
# Cbc0038I Pass   6: suminf.    0.20652 (1) obj. 6.4585 iterations 1203
# Cbc0038I Pass   7: suminf.    0.30876 (1) obj. 6.4585 iterations 422
# Cbc0038I Pass   8: suminf.    0.58575 (3) obj. 6.4585 iterations 578
# Cbc0038I Pass   9: suminf.    0.57742 (3) obj. 6.4585 iterations 44
# Cbc0038I Pass  10: suminf.    0.41801 (1) obj. 6.4585 iterations 414
# Cbc0038I Pass  11: suminf.    0.32919 (1) obj. 6.4585 iterations 474
# Cbc0038I Pass  12: suminf.    0.76919 (3) obj. 6.4585 iterations 767
# Cbc0038I Pass  13: suminf.    0.47597 (1) obj. 6.4585 iterations 355
# Cbc0038I Pass  14: suminf.    0.37597 (1) obj. 6.4585 iterations 400
# Cbc0038I Pass  15: suminf.    1.68296 (6) obj. 6.4585 iterations 616
# Cbc0038I Pass  16: suminf.    0.73288 (2) obj. 6.4585 iterations 783
# Cbc0038I Pass  17: suminf.    0.43993 (1) obj. 6.4585 iterations 618
# Cbc0038I Pass  18: suminf.    0.49786 (1) obj. 6.4585 iterations 200
# Cbc0038I Pass  19: suminf.    1.13425 (5) obj. 6.4585 iterations 688
# Cbc0038I Pass  20: suminf.    0.56954 (2) obj. 6.4585 iterations 1092
# Cbc0038I Pass  21: suminf.    0.81995 (2) obj. 6.4585 iterations 526
# Cbc0038I Pass  22: suminf.    1.59891 (7) obj. 6.4585 iterations 788
# Cbc0038I Pass  23: suminf.    0.52739 (2) obj. 6.4585 iterations 766
# Cbc0038I Pass  24: suminf.    0.79079 (2) obj. 6.4585 iterations 534
# Cbc0038I Pass  25: suminf.    1.77532 (6) obj. 6.4585 iterations 909
# Cbc0038I Pass  26: suminf.    0.47227 (2) obj. 6.4585 iterations 670
# Cbc0038I Pass  27: suminf.    0.77492 (2) obj. 6.4585 iterations 463
# Cbc0038I Pass  28: suminf.    0.90133 (3) obj. 6.4585 iterations 843
# Cbc0038I Pass  29: suminf.    0.47714 (2) obj. 6.4585 iterations 665
# Cbc0038I Pass  30: suminf.    0.47191 (2) obj. 6.4585 iterations 637
# Cbc0038I Pass  31: suminf.    0.46260 (2) obj. 6.4585 iterations 48
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7 integers at bound fixed and 192 continuous
# Cbc0038I Full problem 941 rows 1335 columns, reduced to 908 rows 1126 columns - 20 fixed gives 887, 1105 - still too large
# Cbc0038I Mini branch and bound did not improve solution (4.07 seconds)
# Cbc0038I After 4.07 seconds - Feasibility pump exiting with objective of 7.04034 - took 3.72 seconds
# Cbc0012I Integer solution of 7.0403415 found by feasibility pump after 0 iterations and 0 nodes (4.28 seconds)
# Cbc0031I 156 added rows had average density of 32.929487
# Cbc0013I At root node, 156 cuts changed objective from 1.222057 to 3.6496592 in 14 passes
# Cbc0014I Cut generator 0 (Probing) - 537 row cuts average 3.0 elements, 0 column cuts (40 active)  in 0.044 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 284 row cuts average 39.9 elements, 0 column cuts (0 active)  in 0.071 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.074 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 671 row cuts average 12.8 elements, 0 column cuts (0 active)  in 0.045 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 6 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.081 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 305 row cuts average 47.8 elements, 0 column cuts (0 active)  in 0.081 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 7.0403415 best solution, best possible 3.6496592 (6.76 seconds)
# Cbc0012I Integer solution of 6.366779 found by rounding after 5472 iterations and 22 nodes (11.81 seconds)
# Cbc0038I Full problem 941 rows 1335 columns, reduced to 784 rows 1179 columns - 12 fixed gives 772, 1167 - still too large
# Cbc0001I Search completed - best objective 6.366779031669978, took 12466 iterations and 78 nodes (15.99 seconds)
# Cbc0032I Strong branching done 738 times (23404 iterations), fathomed 0 nodes and fixed 4 variables
# Cbc0035I Maximum depth 19, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 1.22206 to 3.64966
# Probing was tried 96 times and created 1185 cuts of which 40 were active after adding rounds of cuts (0.175 seconds)
# Gomory was tried 96 times and created 514 cuts of which 0 were active after adding rounds of cuts (0.232 seconds)
# Knapsack was tried 14 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.074 seconds)
# Clique was tried 14 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 96 times and created 1766 cuts of which 0 were active after adding rounds of cuts (0.288 seconds)
# FlowCover was tried 14 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.081 seconds)
# TwoMirCuts was tried 96 times and created 476 cuts of which 0 were active after adding rounds of cuts (0.232 seconds)
# ImplicationCuts was tried 67 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.36677903
# Enumerated nodes:               78
# Total iterations:               12466
# Time (CPU seconds):             16.52
# Time (Wallclock seconds):       16.52
#
# Total time (CPU seconds):       16.64   (Wallclock seconds):       16.64
#
# objective function: 6.366779
# WARNING: Implicitly replacing the Component attribute obj (type=<class
# 'pyomo.core.base.objective.ScalarObjective'>) on block unknown with a new
# Component (type=<class 'pyomo.core.base.objective.ScalarObjective'>). This is
# usually indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# Welcome to the CBC MILP Solver
# Version: 2.9.7
# Build Date: Oct 10 2015
# Revision Number: 2226
#
# command line - C:\CBC\win32-msvc12\bin\cbc.exe -printingOptions all -import C:\Users\HP\AppData\Local\Temp\tmpceyuk4vc.pyomo.lp -stat=1 -solve -solu C:\Users\HP\AppData\Local\Temp\tmpceyuk4vc.pyomo.soln (default strategy 1)
# Option for printingOptions changed from normal to all
# Presolve 1352 (-2246) rows, 1748 (-1838) columns and 9925 (-4361) elements
# Statistics for presolved model
# Original problem has 398 integers (398 of which binary)
# Presolved problem has 180 integers (180 of which binary)
# ==== 1738 zero objective 11 different
# 1 variables have objective of -0.720821
# 1 variables have objective of -0.716506
# 1 variables have objective of -0.675109
# 1738 variables have objective of 0
# 1 variables have objective of 0.147884
# 1 variables have objective of 0.343848
# 1 variables have objective of 0.390704
# 1 variables have objective of 0.419724
# 1 variables have objective of 0.60905
# 1 variables have objective of 0.664088
# 1 variables have objective of 1.11033
# ==== absolute objective values 11 different
# 1738 variables have objective of 0
# 1 variables have objective of 0.147884
# 1 variables have objective of 0.343848
# 1 variables have objective of 0.390704
# 1 variables have objective of 0.419724
# 1 variables have objective of 0.60905
# 1 variables have objective of 0.664088
# 1 variables have objective of 0.675109
# 1 variables have objective of 0.716506
# 1 variables have objective of 0.720821
# 1 variables have objective of 1.11033
# ==== for integers 180 zero objective 1 different
# 180 variables have objective of 0
# ==== for integers absolute objective values 1 different
# 180 variables have objective of 0
# ===== end objective counts
#
#
# Problem has 1352 rows, 1748 columns (10 with objective) and 9925 elements
# Column breakdown:
# 0 of type 0.0->inf, 1177 of type 0.0->up, 0 of type lo->inf,
# 391 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 180 of type 0.0->1.0
# Row breakdown:
# 379 of type E 0.0, 0 of type E 1.0, 0 of type E -1.0,
# 10 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 0 of type G other, 783 of type L 0.0, 0 of type L 1.0,
# 180 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Continuous objective value is -14.4281 - 0.06 seconds
# Cgl0003I 1 fixed, 0 tightened bounds, 45 strengthened rows, 0 substitutions
# Cgl0003I 2 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 940 rows, 1335 columns (151 integer (151 of which binary)) and 15087 elements
# Cbc0038I Initial state - 115 integers unsatisfied sum - 25.8691
# Cbc0038I Pass   1: suminf.    1.29620 (10) obj. 22.96 iterations 829
# Cbc0038I Solution found of 22.96
# Cbc0038I Relaxing continuous gives 19.1481
# Cbc0038I Before mini branch and bound, 36 integers at bound fixed and 522 continuous
# Cbc0038I Full problem 940 rows 1335 columns, reduced to 826 rows 756 columns - 18 fixed gives 808, 738 - still too large
# Cbc0038I Full problem 940 rows 1335 columns, reduced to 764 rows 698 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 8 integers at bound fixed and 221 continuous
# Cbc0038I Full problem 940 rows 1335 columns, reduced to 884 rows 1084 columns - 75 fixed gives 811, 1010 - still too large
# Cbc0038I Mini branch and bound did not improve solution (2.69 seconds)
# Cbc0038I After 2.69 seconds - Feasibility pump exiting with objective of 19.1481 - took 2.27 seconds
# Cbc0012I Integer solution of 19.148148 found by feasibility pump after 0 iterations and 0 nodes (2.90 seconds)
# Cbc0038I Full problem 940 rows 1335 columns, reduced to 856 rows 1254 columns - 75 fixed gives 781, 1179 - still too large
# Cbc0031I 180 added rows had average density of 39.5
# Cbc0013I At root node, 180 cuts changed objective from 10.260397 to 13.746857 in 20 passes
# Cbc0014I Cut generator 0 (Probing) - 506 row cuts average 4.5 elements, 0 column cuts (5 active)  in 0.087 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 307 row cuts average 31.3 elements, 0 column cuts (0 active)  in 0.196 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 3 row cuts average 2.7 elements, 0 column cuts (0 active)  in 0.152 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 953 row cuts average 17.5 elements, 0 column cuts (0 active)  in 0.090 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.164 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 332 row cuts average 47.0 elements, 0 column cuts (0 active)  in 0.107 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 19.148148 best solution, best possible 13.746857 (7.59 seconds)
# Cbc0012I Integer solution of 18.551125 found by rounding after 7203 iterations and 32 nodes (20.98 seconds)
# Cbc0038I Full problem 940 rows 1335 columns, reduced to 781 rows 1177 columns - 11 fixed gives 770, 1166 - still too large
# Cbc0012I Integer solution of 18.420381 found by rounding after 8088 iterations and 63 nodes (22.64 seconds)
# Cbc0038I Full problem 940 rows 1335 columns, reduced to 787 rows 1183 columns - 15 fixed gives 772, 1168 - still too large
# Cbc0001I Search completed - best objective 18.42038072256398, took 16213 iterations and 127 nodes (38.63 seconds)
# Cbc0032I Strong branching done 926 times (27102 iterations), fathomed 1 nodes and fixed 5 variables
# Cbc0035I Maximum depth 28, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 10.2604 to 13.7469
# Probing was tried 143 times and created 1227 cuts of which 5 were active after adding rounds of cuts (0.402 seconds)
# Gomory was tried 143 times and created 535 cuts of which 0 were active after adding rounds of cuts (0.592 seconds)
# Knapsack was tried 20 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.152 seconds)
# Clique was tried 20 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 143 times and created 2640 cuts of which 0 were active after adding rounds of cuts (0.675 seconds)
# FlowCover was tried 20 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.164 seconds)
# TwoMirCuts was tried 143 times and created 521 cuts of which 0 were active after adding rounds of cuts (0.451 seconds)
# ImplicationCuts was tried 58 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                18.42038072
# Enumerated nodes:               127
# Total iterations:               16213
# Time (CPU seconds):             39.88
# Time (Wallclock seconds):       39.88
#
# Total time (CPU seconds):       40.04   (Wallclock seconds):       40.04
#
# objective function: 18.420380899999998
# WARNING: Implicitly replacing the Component attribute obj (type=<class
# 'pyomo.core.base.objective.ScalarObjective'>) on block unknown with a new
# Component (type=<class 'pyomo.core.base.objective.ScalarObjective'>). This is
# usually indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# Welcome to the CBC MILP Solver
# Version: 2.9.7
# Build Date: Oct 10 2015
# Revision Number: 2226
#
# command line - C:\CBC\win32-msvc12\bin\cbc.exe -printingOptions all -import C:\Users\HP\AppData\Local\Temp\tmp6g3v01ut.pyomo.lp -stat=1 -solve -solu C:\Users\HP\AppData\Local\Temp\tmp6g3v01ut.pyomo.soln (default strategy 1)
# Option for printingOptions changed from normal to all
# Presolve 1352 (-2246) rows, 1748 (-1838) columns and 9925 (-4361) elements
# Statistics for presolved model
# Original problem has 398 integers (398 of which binary)
# Presolved problem has 180 integers (180 of which binary)
# ==== 1738 zero objective 11 different
# 1 variables have objective of -0.759551
# 1 variables have objective of -0.522156
# 1 variables have objective of -0.144583
# 1 variables have objective of -0.0303885
# 1738 variables have objective of 0
# 1 variables have objective of 0.0288155
# 1 variables have objective of 0.0832865
# 1 variables have objective of 0.241902
# 1 variables have objective of 0.247353
# 1 variables have objective of 0.374008
# 1 variables have objective of 0.3844
# ==== absolute objective values 11 different
# 1738 variables have objective of 0
# 1 variables have objective of 0.0288155
# 1 variables have objective of 0.0303885
# 1 variables have objective of 0.0832865
# 1 variables have objective of 0.144583
# 1 variables have objective of 0.241902
# 1 variables have objective of 0.247353
# 1 variables have objective of 0.374008
# 1 variables have objective of 0.3844
# 1 variables have objective of 0.522156
# 1 variables have objective of 0.759551
# ==== for integers 180 zero objective 1 different
# 180 variables have objective of 0
# ==== for integers absolute objective values 1 different
# 180 variables have objective of 0
# ===== end objective counts
#
#
# Problem has 1352 rows, 1748 columns (10 with objective) and 9925 elements
# Column breakdown:
# 0 of type 0.0->inf, 1177 of type 0.0->up, 0 of type lo->inf,
# 391 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 180 of type 0.0->1.0
# Row breakdown:
# 379 of type E 0.0, 0 of type E 1.0, 0 of type E -1.0,
# 10 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 0 of type G other, 783 of type L 0.0, 0 of type L 1.0,
# 180 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Continuous objective value is -14.8754 - 0.11 seconds
# Cgl0003I 1 fixed, 0 tightened bounds, 48 strengthened rows, 0 substitutions
# Cgl0003I 2 fixed, 0 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0004I processed model has 940 rows, 1335 columns (151 integer (151 of which binary)) and 15087 elements
# Cbc0038I Initial state - 114 integers unsatisfied sum - 25.7626
# Cbc0038I Pass   1: suminf.    0.55835 (5) obj. 7.49716 iterations 901
# Cbc0038I Solution found of 7.49716
# Cbc0038I Relaxing continuous gives 5.6494
# Cbc0038I Before mini branch and bound, 37 integers at bound fixed and 531 continuous
# Cbc0038I Full problem 940 rows 1335 columns, reduced to 807 rows 747 columns - 20 fixed gives 786, 726 - still too large
# Cbc0038I Full problem 940 rows 1335 columns, reduced to 731 rows 674 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (1.69 seconds)
# Cbc0038I Round again with cutoff of 5.13532
# Cbc0038I Pass   2: suminf.    0.85630 (5) obj. 5.13532 iterations 263
# Cbc0038I Pass   3: suminf.    0.15282 (1) obj. 5.13532 iterations 1347
# Cbc0038I Pass   4: suminf.    0.26881 (1) obj. 5.13532 iterations 574
# Cbc0038I Pass   5: suminf.    0.84976 (4) obj. 5.13532 iterations 671
# Cbc0038I Pass   6: suminf.    0.24801 (1) obj. 5.13532 iterations 1292
# Cbc0038I Pass   7: suminf.    0.35506 (1) obj. 5.13532 iterations 514
# Cbc0038I Pass   8: suminf.    0.58438 (4) obj. 5.13532 iterations 660
# Cbc0038I Pass   9: suminf.    0.52260 (4) obj. 5.13532 iterations 158
# Cbc0038I Pass  10: suminf.    0.38003 (1) obj. 5.13532 iterations 603
# Cbc0038I Pass  11: suminf.    0.27499 (1) obj. 5.13532 iterations 673
# Cbc0038I Pass  12: suminf.    1.22744 (8) obj. 5.13532 iterations 898
# Cbc0038I Pass  13: suminf.    0.32916 (1) obj. 5.13532 iterations 807
# Cbc0038I Pass  14: suminf.    0.30669 (1) obj. 5.13532 iterations 618
# Cbc0038I Pass  15: suminf.    1.10391 (4) obj. 5.13532 iterations 473
# Cbc0038I Pass  16: suminf.    0.37219 (1) obj. 5.13532 iterations 479
# Cbc0038I Pass  17: suminf.    0.31716 (1) obj. 5.13532 iterations 549
# Cbc0038I Pass  18: suminf.    1.04975 (4) obj. 5.13532 iterations 689
# Cbc0038I Pass  19: suminf.    0.43698 (1) obj. 5.13532 iterations 743
# Cbc0038I Pass  20: suminf.    0.39311 (1) obj. 5.13532 iterations 386
# Cbc0038I Pass  21: suminf.    1.04293 (7) obj. 5.13532 iterations 735
# Cbc0038I Pass  22: suminf.    0.75933 (2) obj. 5.13532 iterations 1093
# Cbc0038I Pass  23: suminf.    0.40145 (1) obj. 5.13532 iterations 692
# Cbc0038I Pass  24: suminf.    0.48818 (1) obj. 5.13532 iterations 220
# Cbc0038I Pass  25: suminf.    0.81208 (5) obj. 5.13532 iterations 632
# Cbc0038I Pass  26: suminf.    0.78758 (5) obj. 5.13532 iterations 61
# Cbc0038I Pass  27: suminf.    0.78736 (2) obj. 5.13532 iterations 828
# Cbc0038I Pass  28: suminf.    0.42250 (1) obj. 5.13532 iterations 696
# Cbc0038I Pass  29: suminf.    0.47679 (1) obj. 5.13532 iterations 137
# Cbc0038I Pass  30: suminf.    0.46246 (3) obj. 5.13532 iterations 785
# Cbc0038I Pass  31: suminf.    0.49125 (1) obj. 5.13532 iterations 553
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 8 integers at bound fixed and 157 continuous
# Cbc0038I Full problem 940 rows 1335 columns, reduced to 897 rows 1154 columns - 19 fixed gives 878, 1135 - still too large
# Cbc0038I Mini branch and bound did not improve solution (5.19 seconds)
# Cbc0038I After 5.19 seconds - Feasibility pump exiting with objective of 5.6494 - took 4.48 seconds
# Cbc0012I Integer solution of 5.649398 found by feasibility pump after 0 iterations and 0 nodes (5.41 seconds)
# Cbc0038I Full problem 940 rows 1335 columns, reduced to 857 rows 1255 columns - 80 fixed gives 776, 1174 - still too large
# Cbc0031I 181 added rows had average density of 27.453039
# Cbc0013I At root node, 181 cuts changed objective from 0.50867616 to 2.1760247 in 28 passes
# Cbc0014I Cut generator 0 (Probing) - 591 row cuts average 4.0 elements, 0 column cuts (26 active)  in 0.133 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 257 row cuts average 36.7 elements, 0 column cuts (0 active)  in 0.263 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 4 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.227 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 851 row cuts average 12.7 elements, 0 column cuts (0 active)  in 0.136 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 6 row cuts average 2.7 elements, 0 column cuts (0 active)  in 0.301 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 257 row cuts average 43.6 elements, 0 column cuts (0 active)  in 0.122 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 5.649398 best solution, best possible 2.1760247 (11.71 seconds)
# Cbc0012I Integer solution of 5.2989725 found by DiveCoefficient after 3657 iterations and 1 nodes (13.71 seconds)
# Cbc0012I Integer solution of 5.0309951 found by DiveCoefficient after 6511 iterations and 8 nodes (27.86 seconds)
# Cbc0012I Integer solution of 5.0215052 found by rounding after 7850 iterations and 38 nodes (30.78 seconds)
# Cbc0038I Full problem 940 rows 1335 columns, reduced to 794 rows 1190 columns - 12 fixed gives 782, 1178 - still too large
# Cbc0038I Full problem 940 rows 1335 columns, reduced to 807 rows 1205 columns - 17 fixed gives 790, 1188 - still too large
# Cbc0001I Search completed - best objective 5.021505179797901, took 25787 iterations and 196 nodes (53.85 seconds)
# Cbc0032I Strong branching done 894 times (32111 iterations), fathomed 1 nodes and fixed 1 variables
# Cbc0035I Maximum depth 28, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0.508676 to 2.17602
# Probing was tried 214 times and created 1956 cuts of which 26 were active after adding rounds of cuts (0.520 seconds)
# Gomory was tried 214 times and created 671 cuts of which 0 were active after adding rounds of cuts (0.725 seconds)
# Knapsack was tried 28 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.227 seconds)
# Clique was tried 28 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 214 times and created 3150 cuts of which 0 were active after adding rounds of cuts (0.841 seconds)
# FlowCover was tried 28 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.301 seconds)
# TwoMirCuts was tried 214 times and created 481 cuts of which 0 were active after adding rounds of cuts (0.492 seconds)
# ImplicationCuts was tried 127 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                5.02150518
# Enumerated nodes:               196
# Total iterations:               25787
# Time (CPU seconds):             54.45
# Time (Wallclock seconds):       54.45
#
# Total time (CPU seconds):       54.65   (Wallclock seconds):       54.65
#
# objective function: 5.02150513
# WARNING: Implicitly replacing the Component attribute obj (type=<class
# 'pyomo.core.base.objective.ScalarObjective'>) on block unknown with a new
# Component (type=<class 'pyomo.core.base.objective.ScalarObjective'>). This is
# usually indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# Welcome to the CBC MILP Solver
# Version: 2.9.7
# Build Date: Oct 10 2015
# Revision Number: 2226
#
# command line - C:\CBC\win32-msvc12\bin\cbc.exe -printingOptions all -import C:\Users\HP\AppData\Local\Temp\tmp_3ykhgjs.pyomo.lp -stat=1 -solve -solu C:\Users\HP\AppData\Local\Temp\tmp_3ykhgjs.pyomo.soln (default strategy 1)
# Option for printingOptions changed from normal to all
# Presolve 1352 (-2246) rows, 1748 (-1838) columns and 9925 (-4361) elements
# Statistics for presolved model
# Original problem has 398 integers (398 of which binary)
# Presolved problem has 180 integers (180 of which binary)
# ==== 1738 zero objective 11 different
# 1 variables have objective of -0.871215
# 1 variables have objective of -0.64394
# 1 variables have objective of -0.375368
# 1 variables have objective of -0.29936
# 1 variables have objective of -0.124562
# 1738 variables have objective of 0
# 1 variables have objective of 0.100883
# 1 variables have objective of 0.135491
# 1 variables have objective of 0.256356
# 1 variables have objective of 0.312624
# 1 variables have objective of 0.676057
# ==== absolute objective values 11 different
# 1738 variables have objective of 0
# 1 variables have objective of 0.100883
# 1 variables have objective of 0.124562
# 1 variables have objective of 0.135491
# 1 variables have objective of 0.256356
# 1 variables have objective of 0.29936
# 1 variables have objective of 0.312624
# 1 variables have objective of 0.375368
# 1 variables have objective of 0.64394
# 1 variables have objective of 0.676057
# 1 variables have objective of 0.871215
# ==== for integers 180 zero objective 1 different
# 180 variables have objective of 0
# ==== for integers absolute objective values 1 different
# 180 variables have objective of 0
# ===== end objective counts
#
#
# Problem has 1352 rows, 1748 columns (10 with objective) and 9925 elements
# Column breakdown:
# 0 of type 0.0->inf, 1177 of type 0.0->up, 0 of type lo->inf,
# 391 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 180 of type 0.0->1.0
# Row breakdown:
# 379 of type E 0.0, 0 of type E 1.0, 0 of type E -1.0,
# 10 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 0 of type G other, 783 of type L 0.0, 0 of type L 1.0,
# 180 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Continuous objective value is -29.176 - 0.06 seconds
# Cgl0003I 1 fixed, 0 tightened bounds, 49 strengthened rows, 0 substitutions
# Cgl0003I 2 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 943 rows, 1336 columns (151 integer (151 of which binary)) and 15144 elements
# Cbc0038I Initial state - 117 integers unsatisfied sum - 25.4933
# Cbc0038I Pass   1: suminf.    0.22240 (5) obj. 4.39165 iterations 740
# Cbc0038I Solution found of 4.39165
# Cbc0038I Relaxing continuous gives 3.00407
# Cbc0038I Before mini branch and bound, 33 integers at bound fixed and 548 continuous
# Cbc0038I Full problem 943 rows 1336 columns, reduced to 828 rows 735 columns - 18 fixed gives 812, 718 - still too large
# Cbc0038I Full problem 943 rows 1336 columns, reduced to 764 rows 673 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.85 seconds)
# Cbc0038I Round again with cutoff of 2.32146
# Cbc0038I Pass   2: suminf.    0.50016 (6) obj. 2.32146 iterations 244
# Cbc0038I Pass   3: suminf.    0.16604 (1) obj. 2.32146 iterations 1323
# Cbc0038I Pass   4: suminf.    0.10962 (1) obj. 2.32146 iterations 759
# Cbc0038I Pass   5: suminf.    0.80837 (4) obj. 2.32146 iterations 621
# Cbc0038I Pass   6: suminf.    0.18274 (1) obj. 2.32146 iterations 1301
# Cbc0038I Pass   7: suminf.    0.12501 (1) obj. 2.32146 iterations 728
# Cbc0038I Pass   8: suminf.    1.17031 (6) obj. 2.32146 iterations 692
# Cbc0038I Pass   9: suminf.    0.64047 (5) obj. 2.32146 iterations 58
# Cbc0038I Pass  10: suminf.    0.20045 (1) obj. 2.32146 iterations 1236
# Cbc0038I Pass  11: suminf.    0.12984 (1) obj. 2.32146 iterations 723
# Cbc0038I Pass  12: suminf.    0.71829 (3) obj. 2.32146 iterations 843
# Cbc0038I Pass  13: suminf.    0.29701 (1) obj. 2.32146 iterations 969
# Cbc0038I Pass  14: suminf.    0.31330 (1) obj. 2.32146 iterations 669
# Cbc0038I Pass  15: suminf.    0.96745 (6) obj. 2.32146 iterations 849
# Cbc0038I Pass  16: suminf.    0.25701 (1) obj. 2.32146 iterations 1034
# Cbc0038I Pass  17: suminf.    0.29419 (1) obj. 2.32146 iterations 624
# Cbc0038I Pass  18: suminf.    0.74320 (3) obj. 2.32146 iterations 941
# Cbc0038I Pass  19: suminf.    0.24677 (1) obj. 2.32146 iterations 1090
# Cbc0038I Pass  20: suminf.    0.28221 (1) obj. 2.32146 iterations 678
# Cbc0038I Pass  21: suminf.    1.35295 (4) obj. 2.32146 iterations 895
# Cbc0038I Pass  22: suminf.    0.28872 (1) obj. 2.32146 iterations 825
# Cbc0038I Pass  23: suminf.    0.33755 (1) obj. 2.32146 iterations 572
# Cbc0038I Pass  24: suminf.    0.49411 (3) obj. 2.32146 iterations 957
# Cbc0038I Pass  25: suminf.    0.30036 (1) obj. 2.32146 iterations 858
# Cbc0038I Pass  26: suminf.    0.33004 (1) obj. 2.32146 iterations 501
# Cbc0038I Pass  27: suminf.    0.64599 (2) obj. 2.32146 iterations 534
# Cbc0038I No solution found this major pass
# Cbc0038I After 3.88 seconds - Feasibility pump exiting with objective of 3.00407 - took 3.47 seconds
# Cbc0012I Integer solution of 3.0040747 found by feasibility pump after 0 iterations and 0 nodes (4.11 seconds)
# Cbc0038I Full problem 943 rows 1336 columns, reduced to 865 rows 1263 columns - 73 fixed gives 792, 1190 - still too large

# %%
if max_classification_error_check:

    # print the most adversarial label and the corresponding classification error

    print(f"Most adversarial label: {most_adv_label}")
    print(f"Classification error: {max_classification_error}")
# Out:
# Most adversarial label: 3
# Classification error: 5.5502758
